# %%
# !pip install --user pubchempy
# Out:
# Collecting pubchempy
#   Using cached pubchempy-1.0.5-py3-none-any.whl.metadata (4.3 kB)
# Using cached pubchempy-1.0.5-py3-none-any.whl (21 kB)
# Installing collected packages: pubchempy
# Successfully installed pubchempy-1.0.5

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (4.67.1)

# %%
import sys
# !{sys.executable} -m pip install --user pubchempy
# Out:
# Collecting pubchempy
#   Using cached pubchempy-1.0.5-py3-none-any.whl.metadata (4.3 kB)
# Using cached pubchempy-1.0.5-py3-none-any.whl (21 kB)
# Installing collected packages: pubchempy
# Successfully installed pubchempy-1.0.5

# %%
import site
print(site.getusersitepackages())
# Out:
# /u/ahernandez9/.local/lib/python3.11/site-packages

# %%
import sys, site
sys.path.append(site.getusersitepackages())

# %%
# !pip install --user nistchempy
# Out:
# Collecting nistchempy
#   Using cached nistchempy-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: requests in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from nistchempy) (2.32.4)
# Requirement already satisfied: pandas in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from nistchempy) (2.3.2)
# Collecting bs4 (from nistchempy)
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from bs4->nistchempy) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from beautifulsoup4->bs4->nistchempy) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from beautifulsoup4->bs4->nistchempy) (4.15.0)
# Requirement already satisfied: numpy>=1.23.2 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from pandas->nistchempy) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from pandas->nistchempy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from pandas->nistchempy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from pandas->nistchempy) (2025.2)
# Requirement already satisfied: six>=1.5 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->nistchempy) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from requests->nistchempy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from requests->nistchempy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from requests->nistchempy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from requests->nistchempy) (2025.8.3)
# Using cached nistchempy-1.0.5-py3-none-any.whl (11.4 MB)
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4, nistchempy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nistchempy]2 [nistchempy]
# Successfully installed bs4-0.0.2 nistchempy-1.0.5

# %%
import pubchempy as pcp

# %%
import random
import pandas as pd
import pubchempy as pcp
from tqdm import tqdm

# %%
# !pip install --user nistchempy
# Out:
# Collecting nistchempy
#   Using cached nistchempy-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: requests in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from nistchempy) (2.32.4)
# Requirement already satisfied: pandas in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from nistchempy) (2.3.2)
# Collecting bs4 (from nistchempy)
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from bs4->nistchempy) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from beautifulsoup4->bs4->nistchempy) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from beautifulsoup4->bs4->nistchempy) (4.15.0)
# Requirement already satisfied: numpy>=1.23.2 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from pandas->nistchempy) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from pandas->nistchempy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from pandas->nistchempy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from pandas->nistchempy) (2025.2)
# Requirement already satisfied: six>=1.5 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->nistchempy) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from requests->nistchempy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from requests->nistchempy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from requests->nistchempy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /sw/rh9.4/user/python/conda-env/pytorch-2.8-cu128/lib/python3.11/site-packages (from requests->nistchempy) (2025.8.3)
# Using cached nistchempy-1.0.5-py3-none-any.whl (11.4 MB)
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4, nistchempy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nistchempy]2 [nistchempy]
# Successfully installed bs4-0.0.2 nistchempy-1.0.5

# %%
import re
import time
import random

import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
import nistchempy as nist

# Parameters
N_MOLECULES = 200
N_POINTS = 250
WAVENUMBER_MIN = 400
WAVENUMBER_MAX = 4000
DELAY = 1.0
OUTPUT_FILE = "200mol.csv"


def parse_jdx(jdx_text):
    lines = jdx_text.splitlines()
    def get_header(key):
        for line in lines:
            if line.upper().startswith(f"##{key}="):
                return line.split("=", 1)[1].strip()
        return None

    xfactor = float(get_header("XFACTOR") or 1.0)
    yfactor = float(get_header("YFACTOR") or 1.0)
    firstx = float(get_header("FIRSTX") or 0.0)
    lastx = float(get_header("LASTX") or 0.0)
    npoints = int(get_header("NPOINTS") or 0)
    xydata_type = get_header("XYDATA") or ""

    x_vals = []
    y_vals = []

    if "X++" in xydata_type.upper():
        in_data = False
        for line in lines:
            if "##XYDATA=" in line.upper():
                in_data = True
                continue
            if in_data:
                if line.startswith("##"):
                    break
                tokens = re.split(r"[\s,]+", line.strip())
                if len(tokens) < 2:
                    continue
                try:
                    x0 = float(tokens[0]) * xfactor
                except ValueError:
                    continue
                for tok in tokens[1:]:
                    try:
                        y_vals.append(float(tok) * yfactor)
                        x_vals.append(x0)
                    except ValueError:
                        pass

        if npoints > 0 and y_vals:
            x_vals = np.linspace(firstx * xfactor,
                                 lastx * xfactor,
                                 len(y_vals))
        else:
            x_vals = np.array(x_vals)
        y_vals = np.array(y_vals)

    else:
        in_data = False
        for line in lines:
            if line.startswith("##PEAK") or line.startswith("##XYPOINTS"):
                in_data = True
                continue
            if in_data:
                if line.startswith("##"):
                    break
                parts = re.split(r"[\s,;]+", line.strip())
                if len(parts) >= 2:
                    try:
                        x_vals.append(float(parts[0]) * xfactor)
                        y_vals.append(float(parts[1]) * yfactor)
                    except ValueError:
                        pass
        x_vals = np.array(x_vals)
        y_vals = np.array(y_vals)

    if len(x_vals) < 2:
        return None, None

    if x_vals[0] > x_vals[-1]:
        x_vals = x_vals[::-1]
        y_vals = y_vals[::-1]

    return x_vals, y_vals


def get_ir_spectrum(nist_id):
    try:
        compound = nist.get_compound(nist_id)
        compound.get_ir_spectra()
    except Exception:
        return None, None, None

    if not getattr(compound, "ir_specs", None):
        return None, None, None

    spec = compound.ir_specs[0]
    if not getattr(spec, "jdx_text", None):
        return None, None, None

    x, y = parse_jdx(spec.jdx_text)

    smiles = getattr(compound, "smiles", None)

    return x, y, smiles


def interpolate(x, y):
    mask = (x >= WAVENUMBER_MIN) & (x <= WAVENUMBER_MAX)
    xc = x[mask]
    yc = y[mask]
    if len(xc) < 2:
        return None, None

    f = interp1d(xc, yc,
                 kind="linear",
                 bounds_error=False,
                 fill_value=(yc[0], yc[-1]))
    xn = np.linspace(WAVENUMBER_MIN,
                     WAVENUMBER_MAX,
                     N_POINTS)
    return xn, f(xn)


def main():
    print("Loading compound index…")
    df_all = nist.get_all_data()

    # Filter for entries where "IR Spectrum" is non‑null
    df_ir = df_all.loc[~df_all["IR Spectrum"].isna()].reset_index(drop=True)

    if df_ir.empty:
        print("No IR spectra found in index.")
        return

    # Randomly sample
    df_sample = df_ir.sample(n=min(N_MOLECULES, len(df_ir)),
                             random_state=42)

    rows = []
    for _, row in df_sample.iterrows():
        nist_id = row["ID"]
        name = row["name"]
        casrn = row.get("CAS Registry Number", "")

        print(f"Fetching: {name} (NIST ID: {nist_id})")

        x_raw, y_raw, smiles = get_ir_spectrum(nist_id)
        time.sleep(DELAY)

        if x_raw is None:
            print(f"  No IR data for {name}")
            continue

        xi, yi = interpolate(x_raw, y_raw)
        if xi is None:
            print(f"  Interpolation failed for {name}")
            continue

        row_data = {
            "compound_name": name,
            "casrn": casrn,
            "smiles": smiles or ""
            }

        # Add 250 interpolated points as columns
        for i, value in enumerate(yi):
            row_data[f"point_{i+1}"] = round(float(value), 6)

        rows.append(row_data)

    df_out = pd.DataFrame(rows)
    df_out.to_csv(OUTPUT_FILE, index=False)
    print(f"Saved {len(df_out)} rows → {OUTPUT_FILE}")


if __name__ == "__main__":
    main()
# Out:
# Loading compound index…
# Fetching: Edrophonium chloride (NIST ID: C116381)
# Fetching: Cyclohexaneethanol (NIST ID: C4442799)
# Fetching: Cyclohexanone, 4-methyl- (NIST ID: C589924)
# Fetching: 4-Chloro-3-trifluoromethylphenyl isothiocyanate (NIST ID: C23163862)
# Fetching: 2,4,6-Trihydroxytoluene (NIST ID: C88039)
#   No IR data for 2,4,6-Trihydroxytoluene
# Fetching: 2,3,5,6-Tetramethylbenzyl chloride (NIST ID: C7435838)
# Fetching: Iron oxide, black (NIST ID: B6004681)
# Fetching: Tetramethylhydrazine (NIST ID: C6415129)
# Fetching: 2-Phenylglyoxylamide (NIST ID: C7505922)
# Fetching: Benzoic acid, 3-methyl- (NIST ID: C99047)
# Fetching: Benzonitrile, 3-hydroxy- (NIST ID: C873621)
# Fetching: Bis-2-chloroethyl-2-chloroethylphosphonate (NIST ID: C6294344)
# Fetching: Aniline, 4-bromo-n-tert-butyl- (NIST ID: C36171070)
#   No IR data for Aniline, 4-bromo-n-tert-butyl-
# Fetching: Benzene, 1-nitro-2-phenoxy- (NIST ID: C2216128)
#   No IR data for Benzene, 1-nitro-2-phenoxy-
# Fetching: 1,2-Naphthalenedione, 4-(phenylamino)- (NIST ID: C27828564)
#   No IR data for 1,2-Naphthalenedione, 4-(phenylamino)-
# Fetching: 5-Nitroacenaphthenone-1 (NIST ID: C5386118)
# Fetching: N-iso amyl aniline (NIST ID: B6000177)
#   Interpolation failed for N-iso amyl aniline
# Fetching: p-Methylbenzyl isothiocyanate (NIST ID: C3694460)
# Fetching: Cyclopentanecarboxamide, 2,3-dihydroxy-4-(hydroxymethyl)-2,3-diacetate (NIST ID: C13190799)
# Fetching: Butyric acid hydrazide (NIST ID: C3538656)
# Fetching: 10-Undecyn-1-ol (NIST ID: C2774847)
# Fetching: 1-Phenanthrenecarboxylic acid, 1,2,3,4,4a,4b,5,6,7,9,10,10a-dodecahydro-1,4a-dimethyl-7-(1-methylethylidene)-, [1R-(1α,4aβ,4bα,10aα)]- (NIST ID: C471772)
# Fetching: Propylene Carbonate (NIST ID: C108327)
#   No IR data for Propylene Carbonate
# Fetching: 5(4H)-Oxazolone, 2-methyl-4-(phenylmethylene)- (NIST ID: C881903)
#   No IR data for 5(4H)-Oxazolone, 2-methyl-4-(phenylmethylene)-
# Fetching: Mequinol (NIST ID: C150765)
#   No IR data for Mequinol
# Fetching: 2-Hexanol, 5-methyl- (NIST ID: C627598)
#   No IR data for 2-Hexanol, 5-methyl-
# Fetching: CAS Reg. No. 5024-31-7 (NIST ID: C5024317)
# Fetching: Benzaldehyde, 4-(pentyloxy)- (NIST ID: C5736914)
# Fetching: Bulbocapnine, hydrochloride (NIST ID: C632473)
# Fetching: Methane, trimethoxy- (NIST ID: C149735)
# Fetching: 2-Cyclopenten-1-one, 3-methyl- (NIST ID: C2758181)
# Fetching: P-nitro carbanilic acid, n-dodecyl ester (NIST ID: C94432016)
#   Interpolation failed for P-nitro carbanilic acid, n-dodecyl ester
# Fetching: Diisopropylamine hydrofluoride (NIST ID: B6009687)
# Fetching: 2,4,6(1H,3H,5H)-Pyrimidinetrione, 5-phenyl-1-(phenylmethyl)- (NIST ID: C72846005)
# Fetching: 4-Benzyloxyiodobenzene (NIST ID: C19578688)
# Fetching: 4-Heptanone, 3-ethyl- (NIST ID: C1528252)
# Fetching: O-ethyl-o-(2,4,6-trichlorophenyl)-n-ethylamido thiophosphate (NIST ID: C116401946)
#   Interpolation failed for O-ethyl-o-(2,4,6-trichlorophenyl)-n-ethylamido thiophosphate
# Fetching: D-Campholic acid (NIST ID: C31147565)
# Fetching: Pentanedinitrile (NIST ID: C544138)
#   No IR data for Pentanedinitrile
# Fetching: Sodium metaarsenite (NIST ID: B6000497)
#   Interpolation failed for Sodium metaarsenite
# Fetching: Chromone-3-carboxaldehyde (NIST ID: C17422741)
# Fetching: Ethylthiosulfuric acid, 2-[(1,7,7-trimethylbicyclo[2.2.1.]hept-2-yl)-amino]- (NIST ID: B6010459)
# Fetching: 5,9-Undecadien-2-one, 6,10-dimethyl- (NIST ID: C689678)
# Fetching: Acenaphthene (NIST ID: C83329)
# Fetching: Hydroxytoluic Acid (NIST ID: C83409)
# Fetching: 2-Pentanone, 5-(diethylamino)- (NIST ID: C105146)
# Fetching: 2-Butynoic acid (NIST ID: C590932)
# Fetching: 2-Propanone, [(9-beta-d-ribofuranosyl-9h-purin-6-yl)thio]- (NIST ID: C71052749)
# Fetching: 2-Aminoethanol hydrochloride (NIST ID: C2002246)
#   Interpolation failed for 2-Aminoethanol hydrochloride
# Fetching: Pyrrolidine, n-[2,6-dioxo-4-piperidinyl)acetyl]- (NIST ID: C6939317)
# Fetching: Propane, 1-nitro- (NIST ID: C108032)
# Fetching: Imidazole-4-carboxamide, 1-benzyl-5-(benzylamino)- (NIST ID: C7026484)
# Fetching: 5,5'-Thiodisalicylic acid, dimethyl ester (NIST ID: C24483725)
#   No IR data for 5,5'-Thiodisalicylic acid, dimethyl ester
# Fetching: 2-Cyclohexen-1-ol, 2-methyl-5-(1-methylethenyl)-, propanoate (NIST ID: C97450)
# Fetching: Carbamic acid, n-(2-phenyl-2-propyl), methyl ester (NIST ID: C102414200)
#   Interpolation failed for Carbamic acid, n-(2-phenyl-2-propyl), methyl ester
# Fetching: Hexane, 3-ethyl-4-methyl- (NIST ID: C3074779)
# Fetching: 1,3,2-Dioxaphosphorinane, 5,5-dimethyl-2-phenoxy-, 2-oxide (NIST ID: C884899)
#   Interpolation failed for 1,3,2-Dioxaphosphorinane, 5,5-dimethyl-2-phenoxy-, 2-oxide
# Fetching: N-methyl-p-methoxybenzylamine (NIST ID: C702249)
#   Interpolation failed for N-methyl-p-methoxybenzylamine
# Fetching: Furamide (NIST ID: C609381)
# Fetching: L-Glutamine (NIST ID: C56859)
# Fetching: 4-Chloro-7-(trifluoromethyl)quinoline (NIST ID: C346554)
# Fetching: Hexane, 2,4,4-trimethyl- (NIST ID: C16747301)
# Fetching: 3-Nonyn-1-ol (NIST ID: C31333138)
# Fetching: 1-(2,6-Dichlorophenyl)ethanol (NIST ID: B6004857)
#   No IR data for 1-(2,6-Dichlorophenyl)ethanol
# Fetching: Benzothiazole (NIST ID: C95169)
# Fetching: Oxime of 5-acetyl-4-methyl-4-thiazoline-2-thione (NIST ID: C89691872)
#   Interpolation failed for Oxime of 5-acetyl-4-methyl-4-thiazoline-2-thione
# Fetching: 3-(N,n-di-n-hexylamino)-2-methyl-5-(n-heptyl)-pyrazine (NIST ID: C116403066)
#   Interpolation failed for 3-(N,n-di-n-hexylamino)-2-methyl-5-(n-heptyl)-pyrazine
# Fetching: Sulfaphenazole (NIST ID: C526089)
# Fetching: 1-Methyl-3-trifluoromethyl-2-pyrazolin-5-one (NIST ID: C122431372)
# Fetching: Allyl ethyl ether (NIST ID: C557313)
#   Interpolation failed for Allyl ethyl ether
# Fetching: Cyclopentane, methyl- (NIST ID: C96377)
#   No IR data for Cyclopentane, methyl-
# Fetching: Benzenamine, 2,4,6-trinitro- (NIST ID: C489985)
#   No IR data for Benzenamine, 2,4,6-trinitro-
# Fetching: Naphthalene, 2-methoxy- (NIST ID: C93049)
#   No IR data for Naphthalene, 2-methoxy-
# Fetching: 2,3,4,5,6-pentafluorophenethyl alcohol (NIST ID: C653316)
#   No IR data for 2,3,4,5,6-pentafluorophenethyl alcohol
# Fetching: 2,5-Dimethoxybenzyl alcohol (NIST ID: C33524311)
#   No IR data for 2,5-Dimethoxybenzyl alcohol
# Fetching: Ethanedial, dioxime (NIST ID: C557302)
#   No IR data for Ethanedial, dioxime
# Fetching: p-Decyloxybenzylidene p-butylaniline (NIST ID: C51749292)
# Fetching: 2-Amino-3-benzyl-5-(4-methoxyphenyl)pyrazine-1-oxide (NIST ID: C123437730)
# Fetching: 1,4-Dihydronaphthalene-1,4-dicarboxylic acid (NIST ID: C18274345)
# Fetching: 4-(Trifluoromethyl)benzyl alcohol (NIST ID: C349951)
# Fetching: Stannous oxalate (NIST ID: B6000069)
#   Interpolation failed for Stannous oxalate
# Fetching: Benzaldehyde, 2,3-dimethoxy- (NIST ID: C86511)
# Fetching: 2-(N,n-di-n-butylamino)-3-methyl pyrazine (NIST ID: C116660174)
#   Interpolation failed for 2-(N,n-di-n-butylamino)-3-methyl pyrazine
# Fetching: Naphthalene, decahydro-7-isopropenyl-4a-methyl-1-methylene- (NIST ID: C19069444)
# Fetching: Disulfoton sulfone (NIST ID: C2497065)
# Fetching: Octadeca-9,11-dienoic acid, 8-hydroxy-, methyl ester, trans, trans- (NIST ID: C116595303)
# Fetching: Mafenide (NIST ID: C138396)
# Fetching: 2-Butanone, 1-p-methoxyphenyl- (NIST ID: C53917014)
# Fetching: Octane, 2,2-dimethyl- (NIST ID: C15869871)
# Fetching: Cis-9, trans-12 methyl linoleate (NIST ID: C20221265)
#   Interpolation failed for Cis-9, trans-12 methyl linoleate
# Fetching: N-benzylcyclopropylamine (NIST ID: C13324668)
#   Interpolation failed for N-benzylcyclopropylamine
# Fetching: 3-Ethylcarbazole (NIST ID: C5599495)
# Fetching: dialuminium cobalt tetraoxide (NIST ID: C1333886)
# Fetching: 2,5-Dichlorophenyl isothiocyanate (NIST ID: C3386423)
# Fetching: Urea, 1-(2-chloroethyl)-3-(m-chloropheneyl)- (NIST ID: C13908344)
# Fetching: 3,5,7,9,10-Pentachloro-2,2,3,4,4,5,6,6,7,8,8,9,10,10-tetradecafluorodecanoic acid (NIST ID: C335740)
#   Interpolation failed for 3,5,7,9,10-Pentachloro-2,2,3,4,4,5,6,6,7,8,8,9,10,10-tetradecafluorodecanoic acid
# Fetching: Benzene, 1,3-dinitro- (NIST ID: C99650)
# Fetching: 3,5-Dimethoxybenzoyl chloride (NIST ID: C17213579)
#   No IR data for 3,5-Dimethoxybenzoyl chloride
# Fetching: 1,3-Pentadiene, (Z)- (NIST ID: C1574410)
#   No IR data for 1,3-Pentadiene, (Z)-
# Fetching: Allyl-2,3,6-trichlorophenyl ether (NIST ID: C116435144)
#   No IR data for Allyl-2,3,6-trichlorophenyl ether
# Fetching: 3-(Methylthio)phenyl isothiocyanate (NIST ID: C51333803)
# Fetching: Cyclohexanone, 5-methyl-2-(1-methylethylidene)- (NIST ID: C15932806)
# Fetching: 5-Bromo-2-ethoxybenzaldehyde (NIST ID: C79636945)
# Fetching: Benzoic acid, 2-[(phenylmethyl)amino]- (NIST ID: C6622555)
# Fetching: 3,5-Bis(trifluoromethyl)bromobenzene (NIST ID: C328701)
# Fetching: 2,6-Methano-3-benzazocin-8-ol, 1,2,3,4,5,6-hexahydro-3-allyl-6,11-dimethyl- (NIST ID: C7619354)
# Fetching: Barium caprylate (NIST ID: B6001067)
#   Interpolation failed for Barium caprylate
# Fetching: Ethylene glycol bis(3,5-dinitrobenzoate) (NIST ID: C60317397)
#   Interpolation failed for Ethylene glycol bis(3,5-dinitrobenzoate)
# Fetching: Cyclopentane, 1-ethyl-2-methyl-, cis- (NIST ID: C930892)
# Fetching: 1,2-Dimethoxy-4,5-dinitrobenzene (NIST ID: C3395037)
# Fetching: 1,4-Decadiyne (NIST ID: C929533)
# Fetching: 5-Chloro-2-nitrobenzotrifluoride (NIST ID: C118832)
# Fetching: Benzenesulfonamide, N,4-dimethyl-N-nitroso- (NIST ID: C80115)
#   Interpolation failed for Benzenesulfonamide, N,4-dimethyl-N-nitroso-
# Fetching: Acetamide, 2-cyano- (NIST ID: C107915)
# Fetching: [1,1':3',1''-Terphenyl]-2'-ol (NIST ID: C2432113)
#   No IR data for [1,1':3',1''-Terphenyl]-2'-ol
# Fetching: 1,2-Propanedithiol (NIST ID: C814675)
# Fetching: Pyrazine, methoxy- (NIST ID: C3149288)
# Fetching: Pyrimido[5,4-e]-as-triazine, 5-(ethylamino)- (NIST ID: C19359605)
# Fetching: Piperidine hydrochloride (NIST ID: B6010249)
# Fetching: 7H-imidazo[4,5-d]-v-triazin-4-ol, 7-butyl-, (keto form) (NIST ID: B6008701)
# Fetching: 5-Amino-2-methoxyphenol (NIST ID: C1687532)
# Fetching: 1-Pentene, 4-methyl- (NIST ID: C691372)
# Fetching: Dibenzyl, 4,4'-difluoro-2,2'-dinitro- (NIST ID: C50618923)
#   No IR data for Dibenzyl, 4,4'-difluoro-2,2'-dinitro-
# Fetching: 1,1'-Biphenyl, 4-fluoro- (NIST ID: C324743)
#   No IR data for 1,1'-Biphenyl, 4-fluoro-
# Fetching: Epiandrosterone (NIST ID: C481298)
#   No IR data for Epiandrosterone
# Fetching: 2-Chloro-4-fluorobenzamide (NIST ID: C88578909)
# Fetching: Benzene, (azidomethyl)- (NIST ID: C622797)
# Fetching: Silane, methyl- (NIST ID: C992949)
# Fetching: 5-Hepten-2-one, 6-methyl- (NIST ID: C110930)
#   No IR data for 5-Hepten-2-one, 6-methyl-
# Fetching: 2-[(2-Hydroxybenzoyl)oxy]ethyl salicylate (NIST ID: C20210973)
#   No IR data for 2-[(2-Hydroxybenzoyl)oxy]ethyl salicylate
# Fetching: Hydrazine, (2,4-dinitrophenyl)- (NIST ID: C119266)
#   Interpolation failed for Hydrazine, (2,4-dinitrophenyl)-
# Fetching: 2-Heptanol, 5-methyl- (NIST ID: C54630501)
# Fetching: 1,2,5-Selenadiazole-3-carboxamide, 4-amino-n-methyl- (NIST ID: C7698911)
# Fetching: 2-Ethylidenecyclohexanone (NIST ID: C1122243)
# Fetching: 2,6-Dinitrobenzonitrile (NIST ID: C35213004)
# Fetching: Benzene, 1,4-bis(1-methylethenyl)- (NIST ID: C1605181)
# Fetching: Benzoic acid, o-mercapto-, methyl ester (NIST ID: C4892028)
# Fetching: N-(3-aminopropyl)-2-mercaptopropionamide (NIST ID: C816773)
# Fetching: Sodium molybdate (NIST ID: B6000473)
#   Interpolation failed for Sodium molybdate
# Fetching: 1-Propanone, 1-cyclohexyl-2-hydroxy-, m-carbanilate (NIST ID: B6007926)
# Fetching: (Z)-4-Methyl-2-hexene (NIST ID: C3683190)
# Fetching: N,N-Diisopropylformamide (NIST ID: C2700303)
# Fetching: Sulfonyl-o,o'-diphenacyldibenzoate (NIST ID: B6000043)
#   Interpolation failed for Sulfonyl-o,o'-diphenacyldibenzoate
# Fetching: Fumaric acid, bis-(2,2,2-trifluoroethyl)ester- (NIST ID: C352283)
# Fetching: 1-Isopropyl-4-methylbicyclo[3.1.0]hexane (NIST ID: B6004990)
#   No IR data for 1-Isopropyl-4-methylbicyclo[3.1.0]hexane
# Fetching: Benzenemethanol, 2-chloro-α-methyl- (NIST ID: C13524044)
# Fetching: Lidocaine (NIST ID: C137586)
# Fetching: 3-Butyn-2-ol (NIST ID: C2028639)
# Fetching: Cyclododecylamine, n-methyl-, (NIST ID: C40221532)
# Fetching: 1-Phenyl-1-butanol (NIST ID: C22144601)
# Fetching: Betaine Hydrochloride (NIST ID: C590465)
#   Interpolation failed for Betaine Hydrochloride
# Fetching: m-Tolyl isothiocyanate (NIST ID: C621307)
# Fetching: Propane, 2,2-dichloro- (NIST ID: C594207)
# Fetching: 2-Benzothiazolinethione, 3-(o-chloroanilinomethyl)- (NIST ID: C116400954)
#   No IR data for 2-Benzothiazolinethione, 3-(o-chloroanilinomethyl)-
# Fetching: 6-Pentadecanone (NIST ID: C1001452)
#   No IR data for 6-Pentadecanone
# Fetching: 1,4-Bis(2-hydroxyethyl)piperazine (NIST ID: C122963)
#   No IR data for 1,4-Bis(2-hydroxyethyl)piperazine
# Fetching: 8-Azaguanine (NIST ID: C134587)
# Fetching: Ethylenediamine, n-allyl- (NIST ID: C40510223)
# Fetching: 3-Amino-p-toluene sulfonic acid (NIST ID: B6001362)
#   Interpolation failed for 3-Amino-p-toluene sulfonic acid
# Fetching: Ethylene, 2-bromo-1,1-diphenyl- (NIST ID: C13249586)
# Fetching: Purine-8-methanol (NIST ID: C6642268)
# Fetching: Phenol, 3-amino- (NIST ID: C591275)
# Fetching: Ethane, 1,1,1,2-tetrachloro-2,2-difluoro- (NIST ID: C76119)
#   Interpolation failed for Ethane, 1,1,1,2-tetrachloro-2,2-difluoro-
# Fetching: Isothiazole, 4-phenyl- (NIST ID: C936469)
# Fetching: 4-Pyrrolidinobenzaldehyde (NIST ID: C51980542)
# Fetching: 5-Ethyl-5-methoxazolidine-2,4-dione (NIST ID: C52387527)
#   Interpolation failed for 5-Ethyl-5-methoxazolidine-2,4-dione
# Fetching: Anisole (NIST ID: C100663)
# Fetching: (P-trimethylsiloxy)trimethylsilyl benzene (NIST ID: C18036812)
#   Interpolation failed for (P-trimethylsiloxy)trimethylsilyl benzene
# Fetching: 1-Methyl-1-phenyl-hydrazine sulfate (NIST ID: B6003892)
#   Interpolation failed for 1-Methyl-1-phenyl-hydrazine sulfate
# Fetching: 5,8-Endomethylene-5,8-dihydro-1,4-naphthohydroquinone (NIST ID: C3090479)
#   Interpolation failed for 5,8-Endomethylene-5,8-dihydro-1,4-naphthohydroquinone
# Fetching: Cyclohexene, 4-methylene-1-(1-methylethyl)- (NIST ID: C99843)
#   Interpolation failed for Cyclohexene, 4-methylene-1-(1-methylethyl)-
# Fetching: 2,3-Butanedione, mono(O-methyloxime) (NIST ID: C617323)
#   Interpolation failed for 2,3-Butanedione, mono(O-methyloxime)
# Fetching: N,n'-bis(thiosulfatoacetyl)hydrazine, disodium salt (NIST ID: B6004532)
# Fetching: 2-Chloroethyl benzyl sulfide (NIST ID: C4332518)
# Fetching: Imidazole, 4-nitro-5-(propylsulfonyl)- (NIST ID: C99980286)
# Fetching: Butanoic acid, butyl ester (NIST ID: C109217)
# Fetching: Benzeneacetamide, α-amino- (NIST ID: C700630)
# Fetching: Histamine dihydrochloride (NIST ID: B6001870)
#   Interpolation failed for Histamine dihydrochloride
# Fetching: 1,2,3,4-Tetrahydro-1-veratryl-9-pyrid(3,4,b)indole hydrochloride (NIST ID: C107894440)
#   Interpolation failed for 1,2,3,4-Tetrahydro-1-veratryl-9-pyrid(3,4,b)indole hydrochloride
# Fetching: Ethane, 1,1,2,2-tetrabromo- (NIST ID: C79276)
# Fetching: Benzoic acid, 4-methoxy-3-nitro- (NIST ID: C89418)
# Fetching: Dibutyltin-bis-(lauryl mercaptide) (NIST ID: C1185815)
# Fetching: Anthracene, 9-methyl- (NIST ID: C779022)
# Fetching: Acetic acid, (ethylenedinitrilo)-tetra-, cerium sodium salt, hydrate (NIST ID: B6006681)
# Fetching: p-Nitrophenyl nonyl ether (NIST ID: C86702467)
# Fetching: 1,2,3-Propanetricarboxylic acid, 2-hydroxy-, trihexyl ester (NIST ID: C16544700)
# Fetching: Quinoline, 2-methyl- (NIST ID: C91634)
# Fetching: Potassium phosphate, dibasic (NIST ID: B6000579)
#   Interpolation failed for Potassium phosphate, dibasic
# Fetching: Benzene, 1,1'-methylenebis[4-nitro- (NIST ID: C1817749)
#   Interpolation failed for Benzene, 1,1'-methylenebis[4-nitro-
# Fetching: Oxirane, hexyl- (NIST ID: C2984501)
# Fetching: 4-Chloro-2,4-dimethylhexane (NIST ID: C54059766)
# Fetching: Sulfamethoxazole (NIST ID: C723466)
# Fetching: ethyl cyanocycloheptylideneacetate (NIST ID: C7402611)
# Fetching: Purin-8(9h)-one, 6-amino-7-(2-hydroxyethyl)- (NIST ID: B6009821)
# Fetching: 9H-Fluoren-9-ol, acetate (NIST ID: C25017689)
# Fetching: 3,6-Disodium sulfonate, 1,8-dihydroxy naphthalene (NIST ID: B6001354)
#   Interpolation failed for 3,6-Disodium sulfonate, 1,8-dihydroxy naphthalene
# Fetching: 1-Butanol (NIST ID: C71363)
# Fetching: Cyclohexanone, 3,3,5-trimethyl- (NIST ID: C873949)
#   No IR data for Cyclohexanone, 3,3,5-trimethyl-
# Fetching: Urea, [2-(3,4-dichlorophenyl)cyclopropyl]- (NIST ID: C90793412)
#   No IR data for Urea, [2-(3,4-dichlorophenyl)cyclopropyl]-
# Fetching: 6-Methyl-6-hepten-4-yn-2-ol (NIST ID: C20937579)
#   No IR data for 6-Methyl-6-hepten-4-yn-2-ol
# Saved 131 rows → 200mol.csv

# %%
# Get smiles string only CSV

# %%
import rdkit 
import time 
import pandas as pd
import pubchempy as pcp

# %%
input_csv_file = "200mol.csv"
output_csv_file = "200mol_names.csv"

df = pd.read_csv("200mol.csv")

smiles_string_list = []

for names in df["compound_name"]:
    try:
        compound_naming = pcp.get_compounds(names, "name")
        if compound_naming:
            smiles = compounds[0].isomeric_smiles
        else:
            smiles = ""
    except Exception:
        smiles = ""

    smiles_string_list.append(smiles)
    time.sleep(0.1)

df["smiles"] = smiles_string_list 
df.to_csv(output_csv_file, index=False)
print("CSV naming file completed - proceed to the comp data")
# Out:
# CSV naming file completed - proceed to the comp data

# %%
import pandas as pd
import pubchempy as pcp
import time
import re

INPUT_FILE = "200mol.csv"
OUTPUT_FILE = "200mol_names.csv"

df = pd.read_csv(INPUT_FILE)

def clean_name(name):
    name = str(name)

    # Fix "Butane, 1-ol" → "1-ol Butane"
    if "," in name:
        parts = [p.strip() for p in name.split(",")]
        if len(parts) == 2:
            name = parts[1] + " " + parts[0]

    # Remove double spaces
    name = re.sub(r"\s+", " ", name)

    return name.strip()


smiles_list = []

for name in df["compound_name"]:
    cleaned = clean_name(name)

    try:
        compounds = pcp.get_compounds(cleaned, "name")
        if compounds:
            smiles = compounds[0].smiles
        else:
            smiles = ""
    except Exception:
        smiles = ""

    smiles_list.append(smiles)
    time.sleep(0.2)

df["smiles"] = smiles_list
df.to_csv(OUTPUT_FILE, index=False)

print("CSV file created - proceed to the comp data")
# Out:
# CSV file created - proceed to the comp data

# %%
import pandas as pd
import nistchempy as nist
import time

INPUT_FILE = "200mol.csv"
OUTPUT_FILE = "names_with_smiles.csv"

df = pd.read_csv(INPUT_FILE)

smiles_list = []

for name in df["compound_name"]:
    print(f"Fetching SMILES for: {name}")
    smiles = ""

    try:
        # Search compounds by name
        results = nist.search(name=name)
        if results:
            # Loop over results until we find a SMILES
            for r in results:
                try:
                    # Fetch full compound data
                    compound = nist.get_compound(r.ID)
                    if hasattr(compound, "smiles") and compound.smiles:
                        smiles = compound.smiles
                        break  # Stop at first valid SMILES
                except Exception:
                    continue
    except Exception:
        pass

    smiles_list.append(smiles)
    time.sleep(0.2)  # polite delay

df["smiles"] = smiles_list
df.to_csv(OUTPUT_FILE, index=False)
print(f"Done! Saved {len(df)} rows → {OUTPUT_FILE}")
# Out:
# Fetching SMILES for: Edrophonium chloride
# Fetching SMILES for: Cyclohexaneethanol
# Fetching SMILES for: Cyclohexanone, 4-methyl-
# Fetching SMILES for: 4-Chloro-3-trifluoromethylphenyl isothiocyanate
# Fetching SMILES for: 2,3,5,6-Tetramethylbenzyl chloride
# Fetching SMILES for: Iron oxide, black
# Fetching SMILES for: Tetramethylhydrazine
# Fetching SMILES for: 2-Phenylglyoxylamide
# Fetching SMILES for: Benzoic acid, 3-methyl-
# Fetching SMILES for: Benzonitrile, 3-hydroxy-
# Fetching SMILES for: Bis-2-chloroethyl-2-chloroethylphosphonate
# Fetching SMILES for: 5-Nitroacenaphthenone-1
# Fetching SMILES for: p-Methylbenzyl isothiocyanate
# Fetching SMILES for: Cyclopentanecarboxamide, 2,3-dihydroxy-4-(hydroxymethyl)-2,3-diacetate
# Fetching SMILES for: Butyric acid hydrazide
# Fetching SMILES for: 10-Undecyn-1-ol
# Fetching SMILES for: 1-Phenanthrenecarboxylic acid, 1,2,3,4,4a,4b,5,6,7,9,10,10a-dodecahydro-1,4a-dimethyl-7-(1-methylethylidene)-, [1R-(1α,4aβ,4bα,10aα)]-
# Fetching SMILES for: CAS Reg. No. 5024-31-7
# Fetching SMILES for: Benzaldehyde, 4-(pentyloxy)-
# Fetching SMILES for: Bulbocapnine, hydrochloride
# Fetching SMILES for: Methane, trimethoxy-
# Fetching SMILES for: 2-Cyclopenten-1-one, 3-methyl-
# Fetching SMILES for: Diisopropylamine hydrofluoride
# Fetching SMILES for: 2,4,6(1H,3H,5H)-Pyrimidinetrione, 5-phenyl-1-(phenylmethyl)-
# Fetching SMILES for: 4-Benzyloxyiodobenzene
# Fetching SMILES for: 4-Heptanone, 3-ethyl-
# Fetching SMILES for: D-Campholic acid
# Fetching SMILES for: Chromone-3-carboxaldehyde
# Fetching SMILES for: Ethylthiosulfuric acid, 2-[(1,7,7-trimethylbicyclo[2.2.1.]hept-2-yl)-amino]-
# Fetching SMILES for: 5,9-Undecadien-2-one, 6,10-dimethyl-
# Fetching SMILES for: Acenaphthene
# Fetching SMILES for: Hydroxytoluic Acid
# Fetching SMILES for: 2-Pentanone, 5-(diethylamino)-
# Fetching SMILES for: 2-Butynoic acid
# Fetching SMILES for: 2-Propanone, [(9-beta-d-ribofuranosyl-9h-purin-6-yl)thio]-
# Fetching SMILES for: Pyrrolidine, n-[2,6-dioxo-4-piperidinyl)acetyl]-
# Fetching SMILES for: Propane, 1-nitro-
# Fetching SMILES for: Imidazole-4-carboxamide, 1-benzyl-5-(benzylamino)-
# Fetching SMILES for: 2-Cyclohexen-1-ol, 2-methyl-5-(1-methylethenyl)-, propanoate
# Fetching SMILES for: Hexane, 3-ethyl-4-methyl-
# Fetching SMILES for: Furamide
# Fetching SMILES for: L-Glutamine
# Fetching SMILES for: 4-Chloro-7-(trifluoromethyl)quinoline
# Fetching SMILES for: Hexane, 2,4,4-trimethyl-
# Fetching SMILES for: 3-Nonyn-1-ol
# Fetching SMILES for: Benzothiazole
# Fetching SMILES for: Sulfaphenazole
# Fetching SMILES for: 1-Methyl-3-trifluoromethyl-2-pyrazolin-5-one
# Fetching SMILES for: p-Decyloxybenzylidene p-butylaniline
# Fetching SMILES for: 2-Amino-3-benzyl-5-(4-methoxyphenyl)pyrazine-1-oxide
# Fetching SMILES for: 1,4-Dihydronaphthalene-1,4-dicarboxylic acid
# Fetching SMILES for: 4-(Trifluoromethyl)benzyl alcohol
# Fetching SMILES for: Benzaldehyde, 2,3-dimethoxy-
# Fetching SMILES for: Naphthalene, decahydro-7-isopropenyl-4a-methyl-1-methylene-
# Fetching SMILES for: Disulfoton sulfone
# Fetching SMILES for: Octadeca-9,11-dienoic acid, 8-hydroxy-, methyl ester, trans, trans-
# Fetching SMILES for: Mafenide
# Fetching SMILES for: 2-Butanone, 1-p-methoxyphenyl-
# Fetching SMILES for: Octane, 2,2-dimethyl-
# Fetching SMILES for: 3-Ethylcarbazole
# Fetching SMILES for: dialuminium cobalt tetraoxide
# Fetching SMILES for: 2,5-Dichlorophenyl isothiocyanate
# Fetching SMILES for: Urea, 1-(2-chloroethyl)-3-(m-chloropheneyl)-
# Fetching SMILES for: Benzene, 1,3-dinitro-
# Fetching SMILES for: 3-(Methylthio)phenyl isothiocyanate
# Fetching SMILES for: Cyclohexanone, 5-methyl-2-(1-methylethylidene)-
# Fetching SMILES for: 5-Bromo-2-ethoxybenzaldehyde
# Fetching SMILES for: Benzoic acid, 2-[(phenylmethyl)amino]-
# Fetching SMILES for: 3,5-Bis(trifluoromethyl)bromobenzene
# Fetching SMILES for: 2,6-Methano-3-benzazocin-8-ol, 1,2,3,4,5,6-hexahydro-3-allyl-6,11-dimethyl-
# Fetching SMILES for: Cyclopentane, 1-ethyl-2-methyl-, cis-
# Fetching SMILES for: 1,2-Dimethoxy-4,5-dinitrobenzene
# Fetching SMILES for: 1,4-Decadiyne
# Fetching SMILES for: 5-Chloro-2-nitrobenzotrifluoride
# Fetching SMILES for: Acetamide, 2-cyano-
# Fetching SMILES for: 1,2-Propanedithiol
# Fetching SMILES for: Pyrazine, methoxy-
# Fetching SMILES for: Pyrimido[5,4-e]-as-triazine, 5-(ethylamino)-
# Fetching SMILES for: Piperidine hydrochloride
# Fetching SMILES for: 7H-imidazo[4,5-d]-v-triazin-4-ol, 7-butyl-, (keto form)
# Fetching SMILES for: 5-Amino-2-methoxyphenol
# Fetching SMILES for: 1-Pentene, 4-methyl-
# Fetching SMILES for: 2-Chloro-4-fluorobenzamide
# Fetching SMILES for: Benzene, (azidomethyl)-
# Fetching SMILES for: Silane, methyl-
# Fetching SMILES for: 2-Heptanol, 5-methyl-
# Fetching SMILES for: 1,2,5-Selenadiazole-3-carboxamide, 4-amino-n-methyl-
# Fetching SMILES for: 2-Ethylidenecyclohexanone
# Fetching SMILES for: 2,6-Dinitrobenzonitrile
# Fetching SMILES for: Benzene, 1,4-bis(1-methylethenyl)-
# Fetching SMILES for: Benzoic acid, o-mercapto-, methyl ester
# Fetching SMILES for: N-(3-aminopropyl)-2-mercaptopropionamide
# Fetching SMILES for: 1-Propanone, 1-cyclohexyl-2-hydroxy-, m-carbanilate
# Fetching SMILES for: (Z)-4-Methyl-2-hexene
# Fetching SMILES for: N,N-Diisopropylformamide
# Fetching SMILES for: Fumaric acid, bis-(2,2,2-trifluoroethyl)ester-
# Fetching SMILES for: Benzenemethanol, 2-chloro-α-methyl-
# Fetching SMILES for: Lidocaine
# Fetching SMILES for: 3-Butyn-2-ol
# Fetching SMILES for: Cyclododecylamine, n-methyl-,
# Fetching SMILES for: 1-Phenyl-1-butanol
# Fetching SMILES for: m-Tolyl isothiocyanate
# Fetching SMILES for: Propane, 2,2-dichloro-
# Fetching SMILES for: 8-Azaguanine
# Fetching SMILES for: Ethylenediamine, n-allyl-
# Fetching SMILES for: Ethylene, 2-bromo-1,1-diphenyl-
# Fetching SMILES for: Purine-8-methanol
# Fetching SMILES for: Phenol, 3-amino-
# Fetching SMILES for: Isothiazole, 4-phenyl-
# Fetching SMILES for: 4-Pyrrolidinobenzaldehyde
# Fetching SMILES for: Anisole
# Fetching SMILES for: N,n'-bis(thiosulfatoacetyl)hydrazine, disodium salt
# Fetching SMILES for: 2-Chloroethyl benzyl sulfide
# Fetching SMILES for: Imidazole, 4-nitro-5-(propylsulfonyl)-
# Fetching SMILES for: Butanoic acid, butyl ester
# Fetching SMILES for: Benzeneacetamide, α-amino-
# Fetching SMILES for: Ethane, 1,1,2,2-tetrabromo-
# Fetching SMILES for: Benzoic acid, 4-methoxy-3-nitro-
# Fetching SMILES for: Dibutyltin-bis-(lauryl mercaptide)
# Fetching SMILES for: Anthracene, 9-methyl-
# Fetching SMILES for: Acetic acid, (ethylenedinitrilo)-tetra-, cerium sodium salt, hydrate
# Fetching SMILES for: p-Nitrophenyl nonyl ether
# Fetching SMILES for: 1,2,3-Propanetricarboxylic acid, 2-hydroxy-, trihexyl ester
# Fetching SMILES for: Quinoline, 2-methyl-
# Fetching SMILES for: Oxirane, hexyl-
# Fetching SMILES for: 4-Chloro-2,4-dimethylhexane
# Fetching SMILES for: Sulfamethoxazole
# Fetching SMILES for: ethyl cyanocycloheptylideneacetate
# Fetching SMILES for: Purin-8(9h)-one, 6-amino-7-(2-hydroxyethyl)-
# Fetching SMILES for: 9H-Fluoren-9-ol, acetate
# Fetching SMILES for: 1-Butanol
# Done! Saved 131 rows → names_with_smiles.csv
