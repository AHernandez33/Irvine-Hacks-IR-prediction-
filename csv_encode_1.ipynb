# %%
import pandas as pd
# Try reading with 'latin1' if it fails to load as UTF-8
df = pd.read_csv('/u/ahernandez9/ondemand/data/Irvine Hacks/200mol_updated.csv', encoding='latin1')
df.to_csv('/u/ahernandez9/ondemand/data/Irvine Hacks/200mol_updated.csv', index=False, encoding='utf-8')
